# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
loandata=pd.read_csv("/content/income.csv")

# %%
loandata.head()
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    income_level
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
X=loandata.iloc[:,0:6]
y=loandata.iloc[:,6]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
abc=AdaBoostClassifier(n_estimators=100,learning_rate=1)
from sklearn import metrics

# %%
abc.fit(X,y)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=100)

# %%
y_pred=abc.predict(X_test)

# %%
print("accracy",metrics.accuracy_score(y_test,y_pred))
# Out:
# accracy 0.8290510799467704

# %% [markdown]
# # using logistic regression estimator

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)

# %%
abcc=AdaBoostClassifier(n_estimators=50,estimator=lr,learning_rate=1)

# %%
abcc.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(estimator=LogisticRegression(max_iter=1000), learning_rate=1)

# %%
y_pred1=abcc.predict(X_test)

# %%
print("Accuracy",metrics.accuracy_score(y_test,y_pred1))
# Out:
# Accuracy 0.8064284983109837
